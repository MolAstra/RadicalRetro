# %%
import pandas as pd
from pathlib import Path
from rdkit.Chem import AllChem
from tqdm import tqdm

from rdkit import RDLogger

RDLogger.DisableLog('rdApp.*')

# %%
fold = 4

test_src = Path(f"data/radicals/radicals_fold{fold}_test_src.txt")
test_src_pred = Path(f"data/radicals/pure_radicals_fold{fold}_test_src_pred.pickle")

df_test_src_pred = pd.read_pickle(test_src_pred)
df_test_src = pd.read_csv(test_src, header=None, names=["src"])

# %%
df_test_src_pred.head()
# Out:
#                  original_smiles                              prediction_0  \
# 0  C[C](C)C(Sc1ccc(Cl)cc1)=C(C)C  CC(C)=C=C(C)C.Clc1ccc(SSc2ccc(Cl)cc2)cc1
# 1   C[C](C)CC1C(=O)OC(C)(C)OC1=O              C=C(C)C.CC1(C)OC(=O)CC(=O)O1
# 2     COC(=O)[C](CC1CCCCC1)C(C)C                C1CCCCC1.C=C(C(=O)OC)C(C)C
# 3                   C[C](C)C(C)C                               CC(C)=C(C)C
# 4                    CCCC[C](C)C                             [CH2]CCCC(C)C
#
#    log_likelihood_0                              prediction_1  \
# 0         -1.012385  Clc1ccc(SSc2ccc(Cl)cc2)cc1.CC(C)=C=C(C)C
# 1         -1.141239            C1(=O)OC(C)(C)OC(=O)C1.CC(C)=C
# 2         -1.703878             C=C(C(=O)OC)C(C)C.[CH]1CCCCC1
# 3         -1.765476                   CC(C)(C)C(=O)[O-].[Na+]
# 4         -0.969581                                 CCCCC(C)C
#
#    log_likelihood_1                              prediction_2  \
# 0         -3.082054  Clc1ccc(SSc2ccc(Cl)cc2)cc1.CC(=C=C(C)C)C
# 1         -3.470774              CC1(C)OC(=O)CC(=O)O1.CC(C)=C
# 2         -2.405082          C=C(C(=O)OC)C(C)(C)C.[CH]1CCCCC1
# 3         -2.814830                               CC(=C(C)C)C
# 4         -2.444870                          [CH2]CCCC(C)(C)C
#
#    log_likelihood_2                       prediction_3  log_likelihood_3  \
# 0         -3.400374      CC(C)=C=C(C)C.[S]c1ccc(Cl)cc1         -3.653392
# 1         -3.749694     C1(=O)OC(C)(C)OC(=O)C1.C=C(C)C         -3.754506
# 2         -3.191170  C=C(C(=O)OC)C(C)C(C)C.[CH]1CCCCC1         -3.523258
# 3         -3.126765                      CC(C)(C)[C]=O         -3.313148
# 4         -3.303166           CCCCC(C)C(=O)On1ccccc1=S         -3.786431
#
#                                prediction_4  ...  \
# 0  c1cc(Cl)ccc1SSc1ccc(Cl)cc1.CC(C)=C=C(C)C  ...
# 1            C1(=O)OC(C)(C)OC(=O)C1.CC(=C)C  ...
# 2             C1CCCCC1.C=C(C(=O)OC)C(C)(C)C  ...
# 3                            CC(C)(C)C(=O)O  ...
# 4               CCCCC(C)(C)C(=O)On1ccccc1=S  ...
#
#                                  prediction_5 log_likelihood_5  \
# 0  CC(C)=C=C(C)C.c1(Cl)ccc(SSc2ccc(Cl)cc2)cc1        -3.798554
# 1                CC1(C)OC(=O)CC(=O)O1.C=C(C)C        -3.782154
# 2              C=C(C(=O)OC)C(C)CC.[CH]1CCCCC1        -3.875998
# 3                       CC(C)(C)C(=O)C(C)(C)C        -3.619048
# 4                              CCCCC(C)C(C)=O        -3.903626
#
#                                  prediction_6 log_likelihood_6  \
# 0  CC(C)=C=C(C)C.c1c(Cl)ccc(SSc2ccc(Cl)cc2)c1        -3.881045
# 1              CC(C)=C.C1(=O)OC(C)(C)OC(=O)C1        -4.023333
# 2                  C1CCCCC1.C=C(C(OC)=O)C(C)C        -4.639268
# 3                       CCO?1(OC(C)(C)C)OCCO1        -3.777797
# 4                             C([CH2])CCC(C)C        -4.078682
#
#                                prediction_7 log_likelihood_7  \
# 0  c1cc(Cl)ccc1SSc1ccc(Cl)cc1.CC(=C=C(C)C)C        -3.907766
# 1            C1(C)(C)OC(=O)CC(=O)O1.CC(C)=C        -4.040052
# 2             C1CC[CH]CC1.C=C(C(=O)OC)C(C)C        -4.661275
# 3              CC(C)(C)C(=O)SSC(=O)C(C)(C)C        -3.896963
# 4                           C(CCC[CH2])(C)C        -4.343136
#
#                                  prediction_8 log_likelihood_8  \
# 0  c1(Cl)ccc(SSc2ccc(Cl)cc2)cc1.CC(C)=C=C(C)C        -4.009844
# 1              C1(C)(C)OC(=O)CC(=O)O1.C=C(C)C        -4.069422
# 2               C1CCCC[CH]1.C=C(C(=O)OC)C(C)C        -4.667475
# 3                               [CH2]C(C)(C)C        -3.994020
# 4                                  CCCCC(C)=C        -4.392956
#
#                                  prediction_9 log_likelihood_9
# 0  c1c(Cl)ccc(SSc2ccc(Cl)cc2)c1.CC(C)=C=C(C)C        -4.039404
# 1            C1(=O)OC(C)(C)OC(=O)C1.C(C)(C)=C        -4.347620
# 2                  C=C(C(=O)OC)C(C)C.C1CCCCC1        -4.996043
# 3                           CCO?(OCC)(OCC)OCC        -4.703094
# 4                      CCCCC(C)C(=O)SC(C)(C)C        -6.087715
#
# [5 rows x 21 columns]

# %%
df_test_src.head()
# Out:
#                                         src
# 0  CC(C)=C=C(C)C.Clc1ccc(SSc2ccc(Cl)cc2)cc1
# 1              C=C(C)C.CC1(C)OC(=O)CC(=O)O1
# 2             C=C(C(=O)OC)C(C)C.[CH]1CCCCC1
# 3                            CC=C(C)C.[CH3]
# 4                             [CH2]CCCC(C)C

# %%
# concat dfs
assert len(df_test_src_pred) == len(df_test_src)
df = df_test_src_pred.copy()
df['src'] = df_test_src['src']
df.columns
# Out:
# Index(['original_smiles', 'prediction_0', 'log_likelihood_0', 'prediction_1',
#        'log_likelihood_1', 'prediction_2', 'log_likelihood_2', 'prediction_3',
#        'log_likelihood_3', 'prediction_4', 'log_likelihood_4', 'prediction_5',
#        'log_likelihood_5', 'prediction_6', 'log_likelihood_6', 'prediction_7',
#        'log_likelihood_7', 'prediction_8', 'log_likelihood_8', 'prediction_9',
#        'log_likelihood_9', 'src'],
#       dtype='object')

# %%
df.tail()
# Out:
#                                         original_smiles  \
# 1754                      CC(C)C(=O)CCS(=O)(=O)c1ccccc1
# 1755             CCOC(=O)C(C(=O)OCC)C(c1ccccc1)C1CCCCC1
# 1756  CC(C)CC(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC...
# 1757                     O=C1[C@H]2CCC[C@H]2N1Cc1ccccc1
# 1758  C=CCN(C12CC(CCB3OC(C)(C)C(C)(C)O3)(C1)C2)S(=O)...
#
#                                            prediction_0  log_likelihood_0  \
# 1754                        C=CS(=O)(=O)c1ccccc1.CC(C)I         -1.779488
# 1755       CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.O=C(O)C1CCCCC1         -1.456381
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -1.097460
# 1757                       O=C(Cl)N(Cc1ccccc1)C1=CCCCC1         -1.380964
# 1758  C=CCB1OC(C)(C)C(C)(C)O1.C=CCN(C12CC(I)(C1)C2)S...         -2.142075
#
#                                            prediction_1  log_likelihood_1  \
# 1754  C=CS(=O)(=O)c1ccccc1.CC1=C(C#N)C(C(C)C)C(C#N)=...         -1.881656
# 1755            CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.IC1CCCCC1         -3.369482
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -2.987500
# 1757                        O=C(Cl)N(Cc1ccccc1)C1=CCCC1         -2.721897
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.C=CC...         -2.257156
#
#                                            prediction_2  log_likelihood_2  \
# 1754  C=CS(=O)(=O)c1ccccc1.CC(C)C[B-](F)(F)F.O=S([O-...         -3.472999
# 1755             C1CCCCC1.CCOC(=O)C(C(=O)OCC)=Cc1ccccc1         -3.502483
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@H](NC(=O)O...         -3.590545
# 1757     CSC(=S)O[C@@H]1CCN2C(=O)C[C@@H]2[C@H]1c1ccccc1         -4.652443
# 1758  C=C(B1OC(C)(C)C(C)(C)O1)c1ccc(C)cc1.C=CCN(C12C...         -2.763927
#
#                                            prediction_3  log_likelihood_3  \
# 1754  C=CS(=O)(=O)c1ccccc1.CC(C)C1C(C(=O)Cl)=C(C)NC(...         -3.699051
# 1755  CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.O=C(O)[C@@H]1CCCCC1         -3.679130
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -4.105329
# 1757  CSC(=S)O[C@@H]1CCN2C(=O)[C@H](OC(=S)Oc3ccccc3)...         -4.829194
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.C=CC...         -3.300266
#
#                                            prediction_4  ...  \
# 1754                  C=CS(=O)(=O)c1ccccc1.CC(C)C(=O)Cl  ...
# 1755             C1CCCCC1.CCOC(=O)C(=Cc1ccccc1)C(=O)OCC  ...
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...  ...
# 1757  CSC(=S)O[C@@H]1CCN2C(=O)[C@H](OC(=S)Oc3ccccc3)...  ...
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...  ...
#
#       log_likelihood_5                                       prediction_6  \
# 1754         -3.799363                       C=CS(=O)(=O)c1ccccc1.CC(C)Br
# 1755         -4.208793          CC=C(C(=O)OCC)C(=O)OCC.O=C(O)[C@@H]1CCCC1
# 1756         -4.796421  C=C(CP(=O)(OC12CC3CC(CC(C1)C3)C2)[C@@H](NC(=O)...
# 1757         -5.206304      CSC(=S)O[C@H]1CCN2C(=O)C[C@@H]2[C@H]1c1ccccc1
# 1758         -4.606577  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_6                                       prediction_7  \
# 1754         -3.936030                      C=CS(=O)(=O)c1ccccc1.CC(C)CBr
# 1755         -4.301467          Brc1ccccc1.C1CCCCC1.C=C(C(=O)OCC)C(=O)OCC
# 1756         -5.398811  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -5.210541  CSC(=S)O[C@@H]1CCN2C(=O)[C@@H](OC(=S)Oc3ccccc3...
# 1758         -4.986522  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_7                                       prediction_8  \
# 1754         -3.970519  C=CS(=O)(=O)c1ccccc1.CC(C)[B-](F)(F)F.O=S([O-]...
# 1755         -4.757905         CC=C(C(=O)OCC)C(=O)OCC.O=C(O)[C@@H]1CCCCC1
# 1756         -5.507856  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@H](NC(=O)O...
# 1757         -5.247696  CSC(=S)O[C@H]1CCN2C(=O)[C@H](OC(=S)Oc3ccccc3)C...
# 1758         -5.180244  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_8                                       prediction_9  \
# 1754         -4.232593               C=CS(=O)(=O)c1ccccc1.CC(C)(C)C(=O)Cl
# 1755         -4.917636  BrC1CCCCC1.CC=C(C(=O)OCC)C(=O)OCC.c1ccc(C(=O)C...
# 1756         -5.520688  C=C(CP(=O)(OC12CC3CC(C1)CC(C3)C2)[C@@H](NC(=O)...
# 1757         -5.384284  CSC(=S)O[C@H]1CCN2C(=O)[C@H](OC(=S)Oc3ccccc3)C...
# 1758         -5.930323  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_9                                                src
# 1754         -4.498920                  C=CS(=O)(=O)c1ccccc1.CC(C)C(=O)Cl
# 1755         -5.746006            CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.IC1CCCCC1
# 1756         -5.752745  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -5.469637                        O=C(Cl)N(Cc1ccccc1)C1=CCCC1
# 1758         -6.297325  C=CB1OC(C)(C)C(C)(C)O1.C=CCN(C12CC(I)(C1)C2)S(...
#
# [5 rows x 22 columns]

# %%
def is_valid(smi: str, ignore=True):
    try:
        mol = AllChem.MolFromSmiles(smi)
        if mol is None:
            return False
        else:
            return True
    except Exception as e:
        if not ignore:
            print(f'Not valid: {e}')
        return False

def cononize(smi: str, ignore=True):
    """标准化

    Args:
        smi (str): 分子 SMILES

    Returns:
        _type_: None
    """
    try:
        return AllChem.MolToSmiles(AllChem.MolFromSmiles(smi), isomericSmiles=False, canonical=True)
    except Exception as e:
        if not ignore:
            print(f'Failed Canonizing: {e}')
        return None

# %%
def print_topn_acc(df, top_n):
    df = df.copy()
    n_correct = 0
    n_valid = 0
    top_n = top_n
    for i, row in tqdm(df.iterrows(), total=len(df)):
        src = cononize(row['src'])
        for j in range(top_n):
            if is_valid(row[f'prediction_{j}']):
                n_valid += 1
        for k in range(top_n):
            if src == cononize(row[f'prediction_{k}']):
                n_correct += 1
                break
    print('-------------->')
    print(f'top {top_n} acc:')
    print(f'valid rate: {n_valid / len(df) / top_n:.2f}')
    print(f'acc: {n_correct / len(df):.2f}')
    print('<--------------')

# %%
for i in [1, 3, 5, 10]:
    print(i)
    print_topn_acc(df, top_n=i)
# Out:
# 1
# 100%|██████████| 1759/1759 [00:00<00:00, 3214.51it/s]
# -------------->
# top 1 acc:
# valid rate: 0.97
# acc: 0.37
# <--------------
# 3
# 100%|██████████| 1759/1759 [00:00<00:00, 1824.21it/s]
# -------------->
# top 3 acc:
# valid rate: 0.96
# acc: 0.53
# <--------------
# 5
# 100%|██████████| 1759/1759 [00:01<00:00, 1314.39it/s]
# -------------->
# top 5 acc:
# valid rate: 0.96
# acc: 0.59
# <--------------
# 10
# 100%|██████████| 1759/1759 [00:02<00:00, 788.67it/s]
# -------------->
# top 10 acc:
# valid rate: 0.95
# acc: 0.63
# <--------------
