# %%
import pandas as pd
from pathlib import Path
from rdkit.Chem import AllChem
from tqdm import tqdm

from rdkit import RDLogger

RDLogger.DisableLog('rdApp.*')

# %%
fold = 4

test_src = Path(f"data/radicals/radicals_fold{fold}_test_src.txt")
test_src_pred = Path(f"data/radicals/radicals_fold{fold}_test_src_pred.pickle")

df_test_src_pred = pd.read_pickle(test_src_pred)
df_test_src = pd.read_csv(test_src, header=None, names=["src"])

# %%
df_test_src_pred.head()
# Out:
#                  original_smiles                              prediction_0  \
# 0  C[C](C)C(Sc1ccc(Cl)cc1)=C(C)C  CC(C)=C=C(C)C.Clc1ccc(SSc2ccc(Cl)cc2)cc1
# 1   C[C](C)CC1C(=O)OC(C)(C)OC1=O              C=C(C)C.CC1(C)OC(=O)CC(=O)O1
# 2     COC(=O)[C](CC1CCCCC1)C(C)C             C=C(C(=O)OC)C(C)C.[CH]1CCCCC1
# 3                   C[C](C)C(C)C                               CC(C)=C(C)C
# 4                    CCCC[C](C)C                             [CH2]CCCC(C)C
#
#    log_likelihood_0                   prediction_1  log_likelihood_1  \
# 0         -0.884243  CC(C)=C=C(C)C.[S]c1ccc(Cl)cc1         -3.246399
# 1         -0.677393   CC1(C)OC(=O)CC(=O)O1.C=C(C)C         -3.811578
# 2         -1.375763     C1CCCCC1.C=C(C(=O)OC)C(C)C         -1.685568
# 3         -0.706229                    CC(=C(C)C)C         -1.599204
# 4         -0.548833                      CCCCC(C)C         -2.274745
#
#                                prediction_2  log_likelihood_2  \
# 0  Clc1ccc(SSc2ccc(Cl)cc2)cc1.CC(C)=C=C(C)C         -3.870852
# 1              CC1(C)OC(=O)CC(=O)O1.CC(C)=C         -4.174962
# 2             C1CCCC[CH]1.C=C(C(=O)OC)C(C)C         -4.051258
# 3                             C(=C(C)C)(C)C         -3.325182
# 4                             CC(C)CCC[CH2]         -2.921938
#
#                                  prediction_3  log_likelihood_3  \
# 0  CC(C)=C=C(C)C.S(Sc1ccc(Cl)cc1)c1ccc(Cl)cc1         -3.890607
# 1                CC1(C)OC(=O)CC(=O)O1.CC(=C)C         -4.438739
# 2               C=C(C(C)C)C(=O)OC.[CH]1CCCCC1         -4.334097
# 3                               C(C)(=C(C)C)C         -3.354131
# 4                 CCCCC(C)(C)C(=O)C(C)(C)CCCC         -3.379554
#
#                                prediction_4  ...  \
# 0  Clc1ccc(SSc2ccc(Cl)cc2)cc1.CC(=C=C(C)C)C  ...
# 1            C1(C)(C)OC(=O)CC(=O)O1.C=C(C)C  ...
# 2             C1CCCC[CH]1.C=C(C(OC)=O)C(C)C  ...
# 3                             C(C)(C)=C(C)C  ...
# 4                          [CH2]CCCC(C)(C)C  ...
#
#                                  prediction_5 log_likelihood_5  \
# 0  c1c(Cl)ccc(SSc2ccc(Cl)cc2)c1.CC(C)=C=C(C)C        -4.242391
# 1                C1C(=O)OC(C)(C)OC1=O.CC(C)=C        -4.602132
# 2               COC(=O)C(C(C)C)=C.C1CCCC[CH]1        -5.466892
# 3                 CC(C)C(C)(C)N=NC(C)(C)C(C)C        -3.908810
# 4                             C(C(C)C)CC[CH2]        -4.284890
#
#                                  prediction_6 log_likelihood_6  \
# 0  c1c(Cl)ccc(SSc2ccc(Cl)cc2)c1.CC(=C=C(C)C)C        -4.252559
# 1              C1(C)(C)OC(=O)CC(=O)O1.CC(C)=C        -4.946634
# 2               C1CCCC[CH]1.C=C(C(C)C)C(=O)OC        -5.821645
# 3                           [CH2]C(C)(C)C(C)C        -4.083132
# 4                               CC(CCC[CH2])C        -4.410666
#
#                                  prediction_7 log_likelihood_7  \
# 0  c1(Cl)ccc(SSc2ccc(Cl)cc2)cc1.CC(C)=C=C(C)C        -4.268621
# 1              C1(C)(C)OC(=O)CC(=O)O1.CC(=C)C        -4.983916
# 2               C1CCCC[CH]1.CC(C)C(=C)C(=O)OC        -5.919198
# 3                                  CC(C)C(C)C        -4.611441
# 4                                 C(C)CCC(C)C        -4.446288
#
#                                  prediction_8 log_likelihood_8  \
# 0  c1(Cl)ccc(SSc2ccc(Cl)cc2)cc1.CC(=C=C(C)C)C        -4.293314
# 1              C1(=O)CC(=O)OC(C)(C)O1.CC(C)=C        -5.052772
# 2                  COC(=O)C(C(C)C)=C.C1CCCCC1        -5.936446
# 3                             CC(C)C(C)(C)N=O        -4.910366
# 4                 CCCCC(C)(C)C(=O)On1ccccc1=S        -4.532073
#
#                                    prediction_9 log_likelihood_9
# 0  c1c(Cl)ccc(SSc2ccc(Cl)cc2)c1.C(C)(=C=C(C)C)C        -5.244719
# 1                C1(=O)CC(=O)OC(C)(C)O1.CC(=C)C        -5.100330
# 2                 C=C(C(=O)OC)C(C)C.C1CCCC[CH]1        -6.115426
# 3                                 CC(C(C)(C)C)C        -5.232866
# 4                               C(CC(C)C)C[CH2]        -4.567515
#
# [5 rows x 21 columns]

# %%
df_test_src.head()
# Out:
#                                         src
# 0  CC(C)=C=C(C)C.Clc1ccc(SSc2ccc(Cl)cc2)cc1
# 1              C=C(C)C.CC1(C)OC(=O)CC(=O)O1
# 2             C=C(C(=O)OC)C(C)C.[CH]1CCCCC1
# 3                            CC=C(C)C.[CH3]
# 4                             [CH2]CCCC(C)C

# %%
# concat dfs
assert len(df_test_src_pred) == len(df_test_src)
df = df_test_src_pred.copy()
df['src'] = df_test_src['src']
df.columns
# Out:
# Index(['original_smiles', 'prediction_0', 'log_likelihood_0', 'prediction_1',
#        'log_likelihood_1', 'prediction_2', 'log_likelihood_2', 'prediction_3',
#        'log_likelihood_3', 'prediction_4', 'log_likelihood_4', 'prediction_5',
#        'log_likelihood_5', 'prediction_6', 'log_likelihood_6', 'prediction_7',
#        'log_likelihood_7', 'prediction_8', 'log_likelihood_8', 'prediction_9',
#        'log_likelihood_9', 'src'],
#       dtype='object')

# %%
df.tail()
# Out:
#                                         original_smiles  \
# 1754                      CC(C)C(=O)CCS(=O)(=O)c1ccccc1
# 1755             CCOC(=O)C(C(=O)OCC)C(c1ccccc1)C1CCCCC1
# 1756  CC(C)CC(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC...
# 1757                     O=C1[C@H]2CCC[C@H]2N1Cc1ccccc1
# 1758  C=CCN(C12CC(CCB3OC(C)(C)C(C)(C)O3)(C1)C2)S(=O)...
#
#                                            prediction_0  log_likelihood_0  \
# 1754                  C=CS(=O)(=O)c1ccccc1.CC(C)C(=O)Cl         -0.582773
# 1755  CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.F[B-](F)(F)C1CCC...         -1.817590
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -0.663287
# 1757                        O=C(Cl)N(Cc1ccccc1)C1=CCCC1         -0.533536
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...         -1.435230
#
#                                            prediction_1  log_likelihood_1  \
# 1754                  C=CS(=O)(=O)c1ccccc1.O=C(Cl)C(C)C         -4.756607
# 1755             C1CCCCC1.CCOC(=O)C(=Cc1ccccc1)C(=O)OCC         -2.844463
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@H](c1ccccc...         -5.873493
# 1757                       O=C(Cl)N(Cc1ccccc1)C1C=CCCC1         -3.282696
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.C=CB...         -2.353090
#
#                                            prediction_2  log_likelihood_2  \
# 1754                  C=CS(=O)(=O)c1ccccc1.CC(C)C(Cl)=O         -5.797539
# 1755       CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.O=C(O)C1CCCCC1         -3.076617
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -6.867303
# 1757                        ClC(=O)N(Cc1ccccc1)C1=CCCC1         -4.087600
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...         -2.554988
#
#                                            prediction_3  log_likelihood_3  \
# 1754                  C=CS(=O)(=O)c1ccccc1.CC(C(Cl)=O)C         -5.860338
# 1755           BrC1CCCCC1.CCOC(=O)C(=Cc1ccccc1)C(=O)OCC         -3.539250
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...         -7.390921
# 1757                        ClC(N(Cc1ccccc1)C1=CCCC1)=O         -4.355433
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...         -2.778816
#
#                                            prediction_4  ...  \
# 1754                  C=CS(=O)(=O)c1ccccc1.CC(C(=O)Cl)C  ...
# 1755            CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.IC1CCCCC1  ...
# 1756  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...  ...
# 1757                        ClC(=O)N(C1=CCCC1)Cc1ccccc1  ...
# 1758  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...  ...
#
#       log_likelihood_5                                       prediction_6  \
# 1754         -6.814171                c1(S(=O)(=O)C=C)ccccc1.CC(C(Cl)=O)C
# 1755         -4.306385             CCOC(=O)C(C(=O)OCC)=Cc1ccccc1.C1CCCCC1
# 1756         -8.305689  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -4.971704                        c1ccccc1CN(C(=O)Cl)C1=CCCC1
# 1758         -5.639749  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.C=CC...
#
#       log_likelihood_6                                       prediction_7  \
# 1754         -6.814200                c1(S(=O)(=O)C=C)ccccc1.CC(C)C(=O)Cl
# 1755         -4.368172             CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.C1CCCCC1
# 1756         -8.612023  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -4.973690                      N(Cc1ccccc1)(C(Cl)=O)C1=CCCC1
# 1758         -5.813535  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_7                                       prediction_8  \
# 1754         -6.974752                c1ccc(S(=O)(=O)C=C)cc1.CC(C)C(=O)Cl
# 1755         -4.647955             CCOC(=O)C(=Cc1ccccc1)C(OCC)=O.C1CCCCC1
# 1756         -8.705261  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -5.327849                      N(Cc1ccccc1)(C1=CCCC1)C(Cl)=O
# 1758         -6.472549  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_8                                       prediction_9  \
# 1754         -6.988790                c1cc(S(=O)(=O)C=C)ccc1.CC(C)C(=O)Cl
# 1755         -5.034212             CCOC(C(C(OCC)=O)=Cc1ccccc1)=O.C1CCCCC1
# 1756         -8.726264  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -5.635375                       O=C(Cl)N(Cc1ccccc1)C1CCCC=C1
# 1758         -6.699675  C=CCN(C12CC(I)(C1)C2)S(=O)(=O)c1ccc(C)cc1.CC1(...
#
#       log_likelihood_9                                                src
# 1754         -7.032176                  C=CS(=O)(=O)c1ccccc1.CC(C)C(=O)Cl
# 1755         -5.093544            CCOC(=O)C(=Cc1ccccc1)C(=O)OCC.IC1CCCCC1
# 1756         -9.058134  C=C(CP(=O)(OC12CC3CC(CC(C3)C1)C2)[C@@H](NC(=O)...
# 1757         -5.665767                        O=C(Cl)N(Cc1ccccc1)C1=CCCC1
# 1758         -6.900135  C=CB1OC(C)(C)C(C)(C)O1.C=CCN(C12CC(I)(C1)C2)S(...
#
# [5 rows x 22 columns]

# %%
def is_valid(smi: str, ignore=True):
    try:
        mol = AllChem.MolFromSmiles(smi)
        if mol is None:
            return False
        else:
            return True
    except Exception as e:
        if not ignore:
            print(f'Not valid: {e}')
        return False

def cononize(smi: str, ignore=True):
    """标准化

    Args:
        smi (str): 分子 SMILES

    Returns:
        _type_: None
    """
    try:
        return AllChem.MolToSmiles(AllChem.MolFromSmiles(smi), isomericSmiles=False, canonical=True)
    except Exception as e:
        if not ignore:
            print(f'Failed Canonizing: {e}')
        return None

# %%
def print_topn_acc(df, top_n):
    df = df.copy()
    n_correct = 0
    n_valid = 0
    top_n = top_n
    for i, row in tqdm(df.iterrows(), total=len(df)):
        src = cononize(row['src'])
        for j in range(top_n):
            if is_valid(row[f'prediction_{j}']):
                n_valid += 1
        for k in range(top_n):
            if src == cononize(row[f'prediction_{k}']):
                n_correct += 1
                break
    print('-------------->')
    print(f'top {top_n} acc:')
    print(f'valid rate: {n_valid / len(df) / top_n:.2f}')
    print(f'acc: {n_correct / len(df):.2f}')
    print('<--------------')

# %%
for i in [1, 3, 5, 10]:
    print(i)
    print_topn_acc(df, top_n=i)
# Out:
# 1
# 100%|██████████| 1759/1759 [00:00<00:00, 2784.07it/s]
# -------------->
# top 1 acc:
# valid rate: 0.98
# acc: 0.67
# <--------------
# 3
# 100%|██████████| 1759/1759 [00:00<00:00, 2031.42it/s]
# -------------->
# top 3 acc:
# valid rate: 0.98
# acc: 0.76
# <--------------
# 5
# 100%|██████████| 1759/1759 [00:01<00:00, 1513.42it/s]
# -------------->
# top 5 acc:
# valid rate: 0.98
# acc: 0.77
# <--------------
# 10
# 100%|██████████| 1759/1759 [00:01<00:00, 950.23it/s]
# -------------->
# top 10 acc:
# valid rate: 0.98
# acc: 0.79
# <--------------
