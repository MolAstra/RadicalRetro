# %%
import pandas as pd
from pathlib import Path
from rdkit.Chem import AllChem
from tqdm import tqdm

from rdkit import RDLogger

RDLogger.DisableLog('rdApp.*')

# %%
# test_src = Path(f"data/seq-to-seq_datasets/uspto_50_test_src.txt")
# test_src_pred = Path(f"data/seq-to-seq_datasets/uspto_50_test_src_pred.pickle")

fold=0
test_src = Path(f"data/radicals/radicals_fold{fold}_test_src.txt")
test_src_pred = Path(f"data/seq-to-seq_datasets/uspto_50_fold{fold}_test_src_pred.pickle")


df_test_src_pred = pd.read_pickle(test_src_pred)
df_test_src = pd.read_csv(test_src, header=None, names=["src"])

# %%
df_test_src_pred.head()
# Out:
#              original_smiles                             prediction_0  \
# 0  C[C](C)C(Sc1ccccc1)=C(C)C               CC(C)=C(Cl)P(C)C.Sc1ccccc1
# 1               C[C](C)CCC#N                            C?(C)(C)CCC#N
# 2    CC[C](CC1CCCCC1)C(=O)OC     CC1(C)OB(CC2CCCCC2)OC1(C)C.COC(=O)Cl
# 3            CCCC[C](CC)CCCC          CC(C)(C)[O-].CCCC[P+](CC)(Cl)CC
# 4         CCCCC[C](CCCC)CCCC  CC(c1cccc([N+](=O)[O-])c1)S(=O)(=O)[O-]
#
#    log_likelihood_0                      prediction_1  log_likelihood_1  \
# 0         -0.744057     CC(C)=C(Cl)?(C)(C)C.Sc1ccccc1         -2.738587
# 1         -3.024118                   C(?(C)(C)C)CC#N         -3.952719
# 2         -1.206836  CC[Mg+].COC(=O)[PH](Cl)CC1CCCCC1         -4.886465
# 3         -2.580906   CC(C)(C)[O-].CCCC[P+](Cl)(CC)CC         -2.949321
# 4         -2.267254           CCCCC[P+](Cl)(CCCC)CCCC         -2.574410
#
#                      prediction_2  log_likelihood_2  \
# 0   CC(C)=C(Cl)P(C)C.[S-]c1ccccc1         -3.038626
# 1           C(CC?(C)(C)C)#N.ClCCl         -4.630625
# 2   CC[Mg+].COC(=O)?(Cl)CC1CCCCC1         -4.894377
# 3  CC(C)(C)[O-].CCCC?(Cl)(CC)CCCC         -3.728987
# 4  CC(C)(C)[O-].CCCCC[P+](Cl)CCCC         -3.002193
#
#                              prediction_3  log_likelihood_3  \
# 0              CC(C)=C(Cl)?(C)C.Sc1ccccc1         -3.621101
# 1                 C(#N)CCCl.C?(C)(C)CCC#N         -4.724921
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.COC(=O)Cl         -5.123425
# 3                       CCCC?(Cl)(CC)CCCC         -3.848066
# 4    CC(C)(C)[O-].CCCCC[P+](Cl)(CCCC)CCCC         -3.361236
#
#                                     prediction_4  ...  \
# 0               CC(C)=C(Cl)[se]1ccccc1.Sc1ccccc1  ...
# 1                        C(CC#N)Cl.C?(C)(C)CCC#N  ...
# 2  CC1(C)OB(CC2CCCCC2)OC1(C)C.COC(=O)?(Cl)(CC)CC  ...
# 3                    CC(C)(C)[O-].CCCC[P+](Cl)CC  ...
# 4                      C(CCC)C[P+](CCCC)(CCCC)Cl  ...
#
#                          prediction_5 log_likelihood_5  \
# 0       CC(C)=C(Cl)[SH](C)C.Sc1ccccc1        -4.191721
# 1                     C(CC?(C)(C)C)#N        -4.781404
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.ClCOC        -5.691888
# 3            CC(C)(C)[O-].CCCC?(Cl)CC        -3.972070
# 4           C(CC)CC[P+](CCCC)(CCCC)Cl        -3.806211
#
#                                prediction_6 log_likelihood_6  \
# 0       CC(C)=C(Cl)[se]1ccccc1.[S-]c1ccccc1        -5.179251
# 1                       C?(C)(C)CCC#N.ClCCl        -4.841944
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.O(C(=O)Cl)C        -5.768682
# 3               CC(c1cccc([N+](=O)[O-])c1)C        -4.026818
# 4             CC(c1cccc(Cl)c1)S(=O)(=O)[O-]        -4.046032
#
#                                prediction_7 log_likelihood_7  \
# 0            C(C)(C)=C(Cl)P(C)C.c1cccc(S)c1        -5.979454
# 1                     C(?(C)(C)C)CC#N.ClCCl        -5.005981
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.O(C)C(=O)Cl        -6.223671
# 3                       CC(C)([O-])C.ClCCCC        -4.052433
# 4                 C(C)CCC[P+](CCCC)(CCCC)Cl        -4.205074
#
#                                prediction_8 log_likelihood_8  \
# 0              C(C)(C)=C(Cl)P(C)C.c1ccccc1S        -6.023277
# 1                    C(C)(C)(C)OC(=O)NCCCCl        -5.471061
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.C(OC)(=O)Cl        -6.229970
# 3           CC(C)(C)[O-].CCCC[P+](CC)(CC)Cl        -4.087610
# 4               CC(c1cccc([N+](=O)[O-])c1)C        -4.230034
#
#                                       prediction_9 log_likelihood_9
# 0                  ClC(=C(C)C)?(C)(C)C.c1cccc(S)c1        -6.420632
# 1                           C(C)(C)(C)OC(=O)NCCC#N        -7.241721
# 2  CC1(C)C(C)(C)OB(CC2CCCCC2)O1.COC(=O)?(CC)(CC)Cl        -7.185836
# 3          CC(c1cccc([N+](=O)[O-])c1)S(=O)(=O)[O-]        -4.258998
# 4          CC(c1cccc([N+]([O-])=O)c1)S(=O)(=O)[O-]        -4.435253
#
# [5 rows x 21 columns]

# %%
df_test_src.head()
# Out:
#                                   src
# 0  CC(C)=C=C(C)C.c1ccc(SSc2ccccc2)cc1
# 1                     C=C(C)C.C=C=[N]
# 2          C=C(CC)C(=O)OC.[CH]1CCCCC1
# 3                   [CH2]CCCC(CC)CCCC
# 4                [CH2]CCCC(CCCC)CCCCC

# %%
# concat dfs
assert len(df_test_src_pred) == len(df_test_src)
df = df_test_src_pred.copy()
df['src'] = df_test_src['src']
df.columns
# Out:
# Index(['original_smiles', 'prediction_0', 'log_likelihood_0', 'prediction_1',
#        'log_likelihood_1', 'prediction_2', 'log_likelihood_2', 'prediction_3',
#        'log_likelihood_3', 'prediction_4', 'log_likelihood_4', 'prediction_5',
#        'log_likelihood_5', 'prediction_6', 'log_likelihood_6', 'prediction_7',
#        'log_likelihood_7', 'prediction_8', 'log_likelihood_8', 'prediction_9',
#        'log_likelihood_9', 'src'],
#       dtype='object')

# %%
df.tail()
# Out:
#                                   original_smiles  \
# 1755         CCOc1ccc(-c2ccc(C(C)CC(=O)OC)cc2)cc1
# 1756             CCOc1cccc(-c2ccc(CCC(C)=O)cc2)c1
# 1757                                   CCO[C]1CC1
# 1758  C[C](C)c1ccccc1C1(C)[C](c2ccccc2)C1c1ccccc1
# 1759    [CH2]c1ccccc1C1(C)[C](c2ccccc2)C1c1ccccc1
#
#                                        prediction_0  log_likelihood_0  \
# 1755    CCOc1ccc(B(O)O)cc1.COC(=O)CC(C)c1ccc(Br)cc1         -1.355692
# 1756        CC(=O)CCc1ccc(Br)cc1.CCOc1cccc(B(O)O)c1         -0.968045
# 1757                                     CCO.ClCCCl         -2.961202
# 1758  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)Cl         -1.232854
# 1759   CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.Cl?(Cl)Cl         -2.263916
#
#                                            prediction_1  log_likelihood_1  \
# 1755            CCOc1ccc(-c2ccc(C(C)(O)CC(=O)OC)cc2)cc1         -1.515008
# 1756            CCOc1cccc(B(O)O)c1.CC(=O)CCc1ccc(Br)cc1         -2.288339
# 1757                                         CCO.ClCCBr         -3.342257
# 1758  CC1(c2ccccc2)C(c2ccccc2)[Se]C1c1ccccc1.C?(C)(C)Cl         -3.907987
# 1759      CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)Cl         -2.568136
#
#                                          prediction_2  log_likelihood_2  \
# 1755      CC(CC(=O)OC)c1ccc(Br)cc1.CCOc1ccc(B(O)O)cc1         -3.858303
# 1756        CCOc1cccc(B(O)O)c1.C(CC(=O)C)c1ccc(Br)cc1         -5.897867
# 1757                              CCO.O=S(=O)(Cl)CCCl         -3.593155
# 1758    CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(Cl)C         -3.942866
# 1759  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)[s+]         -2.597249
#
#                                            prediction_3  log_likelihood_3  \
# 1755            CCOc1ccc(-c2ccc(C(C)(O)CC(OC)=O)cc2)cc1         -4.270190
# 1756          CCOc1cccc(B(O)O)c1.C(CC(C)=O)c1ccc(Br)cc1         -5.918127
# 1757                             CC1(C)OB(C2CC2)OC1(C)C         -3.812688
# 1758   CC1(c2ccccc2)C(c2ccccc2)C1(C)c1ccccc1.C?(C)(C)Cl         -3.999912
# 1759  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)[N-...         -4.151680
#
#                                            prediction_4  ...  \
# 1755            CCOc1ccc(-c2ccc(C(C)(CC(=O)OC)O)cc2)cc1  ...
# 1756          CCOc1cccc(B(O)O)c1.C(CCc1ccc(Br)cc1)(=O)C  ...
# 1757                                       CCOP1(=O)CC1  ...
# 1758      C?(C)(C)Cl.CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1  ...
# 1759  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)[s+...  ...
#
#       log_likelihood_5                                       prediction_6  \
# 1755         -6.908490          c1(-c2ccc(O)cc2)ccc(C(C)CC(OC)=O)cc1.CCBr
# 1756         -6.574612          c1(OCC)cccc(B(O)O)c1.c1cc(CCC(=O)C)ccc1Br
# 1757         -5.075529                               CC1(C)OB(CBr)OC1(C)C
# 1758         -4.612513  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C[SH](C)(Cl)=O
# 1759         -4.344121  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.CC(C)(C)OC(...
#
#       log_likelihood_6                                       prediction_7  \
# 1755         -6.925331          c1(-c2ccc(O)cc2)ccc(C(C)CC(=O)OC)cc1.CCBr
# 1756         -6.949807          c1(OCC)cccc(B(O)O)c1.c1cc(CCC(C)=O)ccc1Br
# 1757         -5.201563                         CC1(C)OB(C2CC2)OC1(C)C.CCO
# 1758         -5.039822    C1(C)(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(Cl)C
# 1759         -4.387987  CC1(c2ccccc2)C(c2ccccc2)C(c2ccccc2)[Se]1.C?(C)...
#
#       log_likelihood_7                                       prediction_8  \
# 1755         -6.980936        c1c(-c2ccc(C(CC(=O)OC)C)cc2)ccc(O)c1.C(C)Br
# 1756         -7.001109          c1(CCC(=O)C)ccc(Br)cc1.c1ccc(OCC)cc1B(O)O
# 1757         -5.946537                           CC1(C)OB(CBr)OC1(C)C.OCC
# 1758         -6.217087  c1ccc(C2(C)C(c3ccccc3)C2c2ccccc2)c(Cl)c1.C?(C)...
# 1759         -4.502804  CC1(c2ccccc2)C(c2ccccc2)C(c2ccccc2)[Se]1.Cl?(C...
#
#       log_likelihood_8                                       prediction_9  \
# 1755         -7.478811        c1(-c2ccc(O)cc2)ccc(C(C)CC(OC)=O)cc1.C(C)Br
# 1756         -7.182806          c1(CCC(=O)C)ccc(Br)cc1.c1c(OCC)cccc1B(O)O
# 1757         -6.091048                CC(C)(C)OC(=O)N1CC(C)(C)C2CC1C(=O)O
# 1758         -6.479902  c1cc(C2(C)C(c3ccccc3)C2c2ccccc2)c(Cl)cc1.C?(C)...
# 1759         -4.636138  CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)c1c...
#
#       log_likelihood_9                                        src
# 1755         -7.605466  CC=CC(=O)OC.CCOc1ccc(-c2ccc(B(O)O)cc2)cc1
# 1756         -7.356917    C=CC(C)=O.CCOc1cccc(-c2ccc(B(O)O)cc2)c1
# 1757         -7.074028                               CCOC1(Br)CC1
# 1758         -6.549325   CC(C)c1ccccc1C1(C)C(c2ccccc2)=C1c1ccccc1
# 1759         -5.489737       Cc1ccccc1C1(C)C(c2ccccc2)=C1c1ccccc1
#
# [5 rows x 22 columns]

# %%
def is_valid(smi: str, ignore=True):
    try:
        mol = AllChem.MolFromSmiles(smi)
        if mol is None:
            return False
        else:
            return True
    except Exception as e:
        if not ignore:
            print(f'Not valid: {e}')
        return False

def cononize(smi: str, ignore=True):
    """标准化

    Args:
        smi (str): 分子 SMILES

    Returns:
        _type_: None
    """
    try:
        return AllChem.MolToSmiles(AllChem.MolFromSmiles(smi), isomericSmiles=False, canonical=True)
    except Exception as e:
        if not ignore:
            print(f'Failed Canonizing: {e}')
        return None

# %%
def print_topn_acc(df, top_n):
    df = df.copy()
    n_correct = 0
    n_valid = 0
    top_n = top_n
    for i, row in tqdm(df.iterrows(), total=len(df)):
        src = cononize(row['src'])
        for j in range(top_n):
            if is_valid(row[f'prediction_{j}']):
                n_valid += 1
        for k in range(top_n):
            if src == cononize(row[f'prediction_{k}']):
                n_correct += 1
                break
    print('-------------->')
    print(f'top {top_n} acc:')
    print(f'valid rate: {n_valid / len(df) / top_n:.2f}')
    print(f'acc: {n_correct / len(df):.2f}')
    print('<--------------')

# %%
if is_valid("CC1(c2ccccc2)C(c2ccccc2)C1c1ccccc1.C?(C)(C)Cl"):
    print(12)

# %%
for i in [1, 3, 5, 10]:
    print(i)
    print_topn_acc(df, top_n=i)
# Out:
# 1
# 100%|██████████| 1760/1760 [00:00<00:00, 3232.40it/s]
# -------------->
# top 1 acc:
# valid rate: 0.95
# acc: 0.00
# <--------------
# 3
# 100%|██████████| 1760/1760 [00:01<00:00, 1629.76it/s]
# -------------->
# top 3 acc:
# valid rate: 0.95
# acc: 0.00
# <--------------
# 5
# 100%|██████████| 1760/1760 [00:01<00:00, 1086.36it/s]
# -------------->
# top 5 acc:
# valid rate: 0.95
# acc: 0.00
# <--------------
# 10
# 100%|██████████| 1760/1760 [00:02<00:00, 599.21it/s]
# -------------->
# top 10 acc:
# valid rate: 0.95
# acc: 0.01
# <--------------
